# %% [markdown]
# ### Loading and Exploring Data

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("Project\heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
data.shape
# Out:
# (299, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
data.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
data.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# ### EDA

# %%
#clasess distribution

lenlives = len(data["DEATH_EVENT"][data.DEATH_EVENT==0])
lendeath = len(data["DEATH_EVENT"][data.DEATH_EVENT==1])

arr = np.array([lenlives,lendeath])
labels = ["Living",'Died']
print("Total number of living cases : ",lenlives)
print("Total number of death cases : ",lendeath)

plt.pie(arr, labels=labels, explode=[0.2,0.0], shadow=True)
plt.show() #imbalance data
# Out:
# Total number of living cases :  203
# Total number of death cases :  96

# %%
#distribution of age to see other columns distribution

sns.displot(data["age"])
plt.show()

# %%
#age above 50 died or not
above50_notdied = data['DEATH_EVENT'][data.age >= 50][data.DEATH_EVENT==0]
above50_died = data['DEATH_EVENT'][data.age >= 50][data.DEATH_EVENT==1]

lendied = len(above50_died)
lennondied = len(above50_notdied)

arr1 = [lendied,lennondied]
labels = ['Died','Not Died']
print("Total number of living cases : ",lendied)
print("Total number of death cases : ",lennondied)

plt.pie(arr1, labels=labels, explode=[0.2,0.0], shadow=True)
plt.show() #imbalance data
# Out:
# Total number of living cases :  85
# Total number of death cases :  167

# %%
#has diabetes died or not
dt_notdied = data['DEATH_EVENT'][data.diabetes == 0][data.DEATH_EVENT==0]
dt_died = data['DEATH_EVENT'][data.diabetes == 1][data.DEATH_EVENT==1]

len_ddied = len(dt_died)
len_dnondied = len(dt_notdied)

arr2 = [len_ddied,len_dnondied]
labels = ['Died with Diabetes','Not Died with Diabetes']
print("Total number of living cases : ",len_ddied)
print("Total number of death cases : ",len_dnondied)

plt.pie(arr1, labels=labels, explode=[0.2,0.0], shadow=True)
plt.show() #imbalance data
# Out:
# Total number of living cases :  40
# Total number of death cases :  118

# %%
#correlation of our variables

corr = data.corr()
plt.subplots(figsize=(15,15))
sns.heatmap(corr,annot=True)
data.corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_73ce0_row0_col0, #T_73ce0_row1_col1, #T_73ce0_row2_col2, #T_73ce0_row3_col3, #T_73ce0_row4_col4, #T_73ce0_row5_col5, #T_73ce0_row6_col6, #T_73ce0_row7_col7, #T_73ce0_row8_col8, #T_73ce0_row9_col9, #T_73ce0_row10_col10, #T_73ce0_row11_col11, #T_73ce0_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_73ce0_row0_col1, #T_73ce0_row4_col0, #T_73ce0_row5_col4, #T_73ce0_row12_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_73ce0_row0_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_73ce0_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_73ce0_row0_col4, #T_73ce0_row5_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_73ce0_row0_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_73ce0_row0_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_73ce0_row0_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### Dataset Development

# %%
from sklearn.model_selection import train_test_split

X = data.drop('DEATH_EVENT', axis=1)
y = data["DEATH_EVENT"]

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# ### Feature Engineering

# %%
def add_interaction(X):
    features = X.columns
    m = len(features)
    X_int = X.copy(deep=True)
    
    for i in range(m):
        feature_i_name = features[i]
        feature_i_data = X[feature_i_name]
        
        for j in range(i+1, m):
            feature_j_name = features[j]
            feature_j_data = X[feature_j_name]
            feature_i_j_name = feature_i_name+"_x_"+feature_j_name
            X_int[feature_i_j_name] = feature_i_data*feature_j_data
    return X_int

x_train_mod = add_interaction(X_train)
x_test_mod = add_interaction(X_test)

# %% [markdown]
# ### Model Building

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

def evaluating_model(y_test,y_pred):
    print("Accuracy Score : ", accuracy_score(y_test,y_pred))
    print("Precision Score : ", precision_score(y_test,y_pred))
    print("Recall Score : ", recall_score(y_test,y_pred))
    print("Confusion Matrix: \n", confusion_matrix(y_test,_pred))

# %%
#Logistic regression model as baseline
from sklearn.linear_model import LogisticRegression

lr_clf = LogisticRegression(max_iter = 1000)
lr_clf.fit(X_train,y_train)

y_pred = lr_clf.predict(X_test)
evaluating_model(y_test,y_pred)
# Out:
# Accuracy Score :  0.7888888888888889
# Precision Score :  0.7647058823529411
# Recall Score :  0.4642857142857143
# Confusion Matrix:
#  [[58  4]
#  [15 13]]

# %%
#build with standard scaler because the model doesnt converge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

lr_clf_pip = make_pipeline(StandardScaler(), LogisticRegression())
lr_clf_pip.fit(X_train,y_train)

y_pred1 = lr_clf_pip.predict(X_test)
evaluating_model(y_test,y_pred1)
# Out:
# Accuracy Score :  0.8111111111111111
# Precision Score :  0.7894736842105263
# Recall Score :  0.5357142857142857
# Confusion Matrix:
#  [[58  4]
#  [13 15]]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

def randomized_search(params, runs=20, clf=DecisionTreeClassifier(random_state=2)):
    rand_clf = RandomizedSearchCV(clf, params ,n_iter=runs, n_jobs=-1, random_state=2)
    rand_clf.fit(X_train,y_train)
    best_model = rand_clf.best_estimator_
    best_score = rand_clf.best_score_
    
    print("Training score: ", format(best_score))
    y_pred = best_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("Trest score: ", format(accuracy))

    return best_model

randomized_search(params={
    'min_samples_leaf':[1,2,4,6,8,10,20,30],
    'min_impurity_decrease':[0.0,0.01,0.05,0.10,0.15,0.2],
    'max_features':['auto',0.8,0.7,0.6,0.5,0.4],
    'max_depth':[None,2,4,6,8,10,20]
}, clf = RandomForestClassifier(random_state=2))
# Out:
# Training score:  0.8469221835075492
# Trest score:  0.8666666666666667
# RandomForestClassifier(max_depth=2, max_features=0.5,
#                        min_impurity_decrease=0.01, min_samples_leaf=10,
#                        random_state=2)

# %%
rf_clf = RandomForestClassifier(max_depth=2, max_features=0.5, min_impurity_decrease=0.01, 
                                min_samples_leaf=10, random_state=2)
rf_clf.fit(X_train,y_train)
pred2 = rf_clf.predict(X_test)
evaluating_model(y_test,pred2)
# Out:
# Accuracy Score :  0.8666666666666667
# Precision Score :  0.9
# Recall Score :  0.6428571428571429
# Confusion Matrix:
#  [[60  2]
#  [10 18]]

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier
xgb1 = XGBClassifier(colsample_bytree= 1.0, learning_rate=0.1, max_depth=4, n_estimators=400, subsample=1.0)

eval_set = [(X_test,y_test)]

xgb1.fit(X_train,y_train,early_stopping_rounds=10, eval_metric="logloss", eval_set=eval_set, verbose=True)
# Out:
# C:\Users\kurni\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-logloss:0.63929
# [1]	validation_0-logloss:0.59762
# [2]	validation_0-logloss:0.56422
# [3]	validation_0-logloss:0.53183
# [4]	validation_0-logloss:0.50465
# [5]	validation_0-logloss:0.48130
# [6]	validation_0-logloss:0.46135
# [7]	validation_0-logloss:0.44722
# [8]	validation_0-logloss:0.43508
# [9]	validation_0-logloss:0.42311
# [10]	validation_0-logloss:0.40869
# [11]	validation_0-logloss:0.39828
# [12]	validation_0-logloss:0.39094
# [13]	validation_0-logloss:0.38522
# [14]	validation_0-logloss:0.37836
# ...

# %%
pred3 = xgb1.predict(X_test)
evaluating_model(y_test,pred3)
# Out:
# Accuracy Score :  0.8555555555555555
# Precision Score :  0.8
# Recall Score :  0.7142857142857143
# Confusion Matrix:
#  [[57  5]
#  [ 8 20]]

# %%
from xgboost import plot_importance

plot_importance(xgb1)
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbt = GradientBoostingClassifier(n_estimators=200, learning_rate=0.1, max_depth=1, random_state=0)
gbt.fit(X_train,y_train)

pred4 = gbt.predict(X_test)
evaluating_model(y_test,pred4)
# Out:
# Accuracy Score :  0.8555555555555555
# Precision Score :  0.8571428571428571
# Recall Score :  0.6428571428571429
# Confusion Matrix:
#  [[59  3]
#  [10 18]]

# %% [markdown]
# ### Best Model and Save

# %%
#RandomForest best model
import joblib
joblib.dump(xgb1,'model.pkl')
model = joblib.load('model.pkl')
model.predict(X_test)
